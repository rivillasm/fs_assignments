# %% [markdown]
# # Assignment 11

# %% [markdown]
# 1. Create an assert statement that throws an AssertionError if the variable spam is a negative
# integer.
# ![image.png](attachment:5acdded0-7c74-415e-bc7f-71973c3187ac.png)

# %%
def check(x):
    assert x>0,"The entered value is not positive"
    return f"you enter the +ve value:{x}"
    
value=int(input("Enter a positive integer:"))
check(value)
# Out:
# Enter a positive integer: -2
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-63f748629f86> in <module>()
#       4
#       5 value=int(input("Enter a positive integer:"))
# ----> 6 check(value)
#
# <ipython-input-6-63f748629f86> in check(x)
#       1 def check(x):
# ----> 2     assert x>0,"The entered value is not positive"
#       3     return f"you enter the +ve value:{x}"
#       4
#       5 value=int(input("Enter a positive integer:"))
#
# AssertionError: The entered value is not positive

# %% [markdown]
# 2. Write an assert statement that triggers an AssertionError if the variables eggs and bacon contain
# strings that are the same as each other, even if their cases are different (that is, &#39;hello&#39; and &#39;hello&#39; are
# considered the same, and &#39;goodbye&#39; and &#39;GOODbye&#39; are also considered the same).

# %%
def check(str1,str2):
    assert str1.lower() != str2.lower(),"Both strings are equal!!"
    return f"The content of the variables is different"


eggs="mario"
bacon="Mario"

check(eggs,bacon)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-13-84dda0cc1f60> in <module>()
#       7 bacon="Mario"
#       8
# ----> 9 check(eggs,bacon)
#
# <ipython-input-13-84dda0cc1f60> in check(str1, str2)
#       1 def check(str1,str2):
# ----> 2     assert str1.lower() != str2.lower(),"Both strings are equal!!"
#       3     return f"The content of the variables is different"
#       4
#       5
#
# AssertionError: Both strings are equal!!

# %% [markdown]
# 3. Create an assert statement that throws an AssertionError every time.

# %%
assert 1 == 0,"Always will be produce an error!!"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-3834050229cc> in <module>()
# ----> 1 assert 1 == 0,"Always will be produce an error!!"
#
# AssertionError: Always will be produce an error!!

# %% [markdown]
# 4. What are the two lines that must be present in your software in order to call logging.debug()?

# %%
import logging
logging.basicConfig(filename='example.log', filemode='w', level=logging.DEBUG)

# %% [markdown]
# 5. What are the two lines that your program must have in order to have logging.debug() send a logging message to a file named programLog.txt?

# %%
import logging
logging.basicConfig(filename='programLog.txt', filemode='w', level=logging.DEBUG)

# %% [markdown]
# 6. What are the five levels of logging?
# ![image.png](attachment:abcca8db-c591-4f64-9893-d90254b0b68e.png)

# %% [markdown]
# 7. What line of code would you add to your software to disable all logging messages?
#
# * logging.disable(level = CRITICAL)
#
# ![image.png](attachment:d6a83755-6e9d-47ad-a907-99f6bc79408c.png)

# %% [markdown]
# 8.Why is using logging messages better than using print() to display the same message?

# %% [markdown]
# Logging provides more advantages such as:
# * Defyning the type of information to include in the logs
# * detailed segmentatio of the log events, time and severity
# * configuration on how it looks when emited
# * creates different destination for the logs
# * logging creates a searchable text database

# %% [markdown]
# 9. What are the differences between the Step Over, Step In, and Step Out buttons in the debugger?
# * Step over - an action taken in the debugger that will step over a given line. if the line contains a function the function will be executed and the result returned without debbuging each line
# * step in - an actin to take in the debugger, if the line does not contain a function it behaves the same as step over but if it does the debugger will enter the called function and continue line by line debuggin there
# * step out - an action taken in the debugger that returns to the line where the current function was called

# %% [markdown]
# 10.After you click Continue, when will the debugger stop ?
# * Continue - is the action to take in the debugger that will continue execution until the next breakpoint is reached or the program exits.

# %% [markdown]
# 11. What is the concept of a breakpoint?
# * It is used when debugging a code, it is the line of interest in the program and when the debugger is running it halts execution of the program at that line
