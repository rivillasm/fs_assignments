# %% [markdown]
# # Assignment 17

# %% [markdown]
# ### 1. Assign the value 7 to the variable guess_me. Then, write the conditional tests (if, else, and elif) to print the string &#39;too low&#39; if guess_me is less than 7, &#39;too high&#39; if greater than 7, and &#39;just right&#39; if equal to 7.

# %%
guess_me = 7
if guess_me < 7:
    print("too low")
elif guess_me > 7:
    print("too high")
else :
    print("just right")
# Out:
# just right

# %% [markdown]
# ### 2. Assign the value 7 to the variable guess_me and the value 1 to the variable start. Write a while loop that compares start with guess_me. Print too low if start is less than guess me. If start equals guess_me, print &#39;found it!&#39; and exit the loop. If start is greater than guess_me, print &#39;oops&#39; and exit the loop. Increment start at the end of the loop.

# %%
guess_me = 7
start = 1

while True:
    if start < guess_me:
        print('too low')
    elif start == guess_me:
        print(f'found it! start={start}')
        break
    else:
        print('oops')
        break
    start += 1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it! start=7

# %% [markdown]
# ### 3. Print the following values of the list [3, 2, 1, 0] using a for loop.

# %%
_list=[3,2,1,0]
for i in range(len(_list)):
    print(_list[i])
# Out:
# 3
# 2
# 1
# 0

# %% [markdown]
# ### 4. Use a list comprehension to make a list of the even numbers in range(10)

# %%
 [i for i in range(10) if i%2==0]
# Out:
# [0, 2, 4, 6, 8]

# %% [markdown]
# ### 5. Use a dictionary comprehension to create the dictionary squares. Use range(10) to return the keys, and use the square of each key as its value.

# %%
{i:i**2 for i in range(10)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# ### 6. Construct the set odd from the odd numbers in the range using a set comprehension (10).

# %%
 {i for i in range(10) if i%2==1}
# Out:
# {1, 3, 5, 7, 9}

# %% [markdown]
# ### 7. Use a generator comprehension to return the string &#39;Got &#39; and a number for the numbers in range(10). Iterate through this by using a for loop.

# %%
_string = {"Got"+str(i) for i in range(10)}
print(_string)
for item in _string:
     print(item)
# Out:
# {'Got5', 'Got9', 'Got2', 'Got0', 'Got6', 'Got7', 'Got3', 'Got8', 'Got4', 'Got1'}
# Got5
# Got9
# Got2
# Got0
# Got6
# Got7
# Got3
# Got8
# Got4
# Got1

# %% [markdown]
# ### 8. Define a function called good that returns the list [&#39;Harry&#39;, &#39;Ron&#39;, &#39;Hermione&#39;].

# %%
def good():
    return ['Harry', 'Ron', 'Hermione']

good()
# Out:
# ['Harry', 'Ron', 'Hermione']

# %% [markdown]
# ### 9. Define a generator function called get_odds that returns the odd numbers from range(10). Use a for loop to find and print the third value returned.

# %%
def get_odds(limit):
    return [i for i in range(limit) if i%2==1]


_items = 10
result = get_odds(_items)
for i, ii in enumerate(result):
    if i==2:
        print(result)
        print(f"The third value is: {ii}")
# Out:
# [1, 3, 5, 7, 9]
# The third value is: 5

# %% [markdown]
# ### 10. Define an exception called OopsException. Raise this exception to see what happens. Then write the code to catch this exception and print &#39;Caught an oops&#39;.

# %% [markdown]
# ![image.png](attachment:e6e57da4-08a7-4fb2-9a4d-bce8fd2ac635.png)

# %%
class OopsException(Exception):
    pass

x=-1

try:
    if x<0:
        raise OopsException(x)
except OopsException as e:
    print("'Caught an oops'.")
# Out:
# 'Caught an oops'.

# %% [markdown]
# * Example:
#
# ![image.png](attachment:f761bae6-fa9e-47d7-8964-a3422acc3786.png)

# %% [markdown]
# ### 11. Use zip() to make a dictionary called movies that pairs these lists: titles = [&#39;Creature of Habit&#39;, &#39;Crewel Fate&#39;] and plots = [&#39;A nun turns into a monster&#39;, &#39;A haunted yarn shop&#39;].

# %%
titles = ['Creature of Habit', 'Crewel Fate'] 
plots = ['A nun turns into a monster', 'A haunted yarn shop']
_dictionary = dict(zip(titles,plots))
_dictionary
# Out:
# {'Creature of Habit': 'A nun turns into a monster',
#  'Crewel Fate': 'A haunted yarn shop'}
