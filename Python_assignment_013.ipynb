# %% [markdown]
# # Assignment 13

# %% [markdown]
# ### 1. What advantages do Excel spreadsheets have over CSV spreadsheets?

# %% [markdown]
# ##### EXCEL
# * Binary file format holding information of the wookbooks
# * it is a tool for financial analysis on data and number and not just a source of info
# * Consumes more memory than CSV since is more superior and is slower when importing
# * Can not be edited by text editors but can be passw protected
# * Excel can be opened with Microsoft office only and does not support any other platform when compared to CSV.
#
# ##### CSV
# * Plain text format information with a series of values in a sheet separated by commas
# * csv file is just a source of information and can be generated from any database
# * csv is faster when importing and consumes less memory
# * csv can be edited by text editors but can not be passw protected

# %% [markdown]
# ### 2.What do you pass to csv.reader() and csv.writer() to create reader and writer objects?

# %% [markdown]
# ##### csv.reader(csvfile, dialect, **fmtparams )
# * returns a reader object which will iterateover lines in a given csvfile
# * dialect -optional, to define a set of parameters specificar to a dialect (delimiter,doublequote,quoting..)
# * fmtparams -optional, keyword arguments given to overrride individual formatting params
# ![image.png](attachment:228c34c1-5291-46eb-ae9b-068f146af79f.png)
#
# ##### csv.writer(csvfile, dialect, **fmtparams
# * returns a writer object responsible for converting the user’s data into delimited strings on the given file-like object. csvfile
# ![image.png](attachment:90042843-8b23-44c9-840d-9d1bc339f9bb.png)

# %% [markdown]
# ### 3. What modes do File objects for reader and writer objects need to be opened in?

# %% [markdown]
# ![image.png](attachment:81dc9448-cebe-41c4-847a-370bd20cff07.png)

# %% [markdown]
# ### 4. What method takes a list argument and writes it to a CSV file?
#
# * The most common method to write data from a list to CSV file is the $writerow()$ method of writer and DictWriter class.

# %%
# Importing library
import csv
  
# data to be written row-wise in csv fil
data = [['Geeks'], [4], ['geeks !']]
  
# opening the csv file in 'w+' mode
file = open('g4g.csv', 'w+', newline ='')
  
# writing the data into the file
with file:    
    write = csv.writer(file)
    write.writerows(data)

# %% [markdown]
# ![image.png](attachment:b1f1e2d0-5c75-415f-81d2-0fedc0075e48.png)

# %% [markdown]
# ### 5. What do the keyword arguments delimiter and line terminator do?

# %%
import csv
csvFile = open('example.tsv', 'w', newline='')
csvWriter = csv.writer(csvFile, delimiter='\t', lineterminator='\n\n')
csvWriter.writerow(['apples', 'oranges', 'grapes'])
csvWriter.writerow(['eggs', 'bacon', 'ham'])
csvWriter.writerow(['spam', 'spam', 'spam', 'spam', 'spam', 'spam'])
csvFile.close()

# %% [markdown]
# * Passing delimeter='\t' and lineterminator='\n\n'  changes the character between cells to a tab(instead of a comma as per its default value) and the character between rows to two newlines(instead of a new line as per its defualt value). We then call writerow() three times to give us three rows.
#
# ![image.png](attachment:23166e0d-9806-4742-9720-3ab905ae3bbd.png)

# %% [markdown]
# ### 6. What function takes a string of JSON data and returns a Python data structure?
#
# * Deserializing JSON :
# Deserialization is the opposite of Serialization, i.e. conversion of JSON objects into their respective Python objects. The $load() method$ is used for it. If you have used JSON data from another program or obtained it as a string format of JSON, then it can easily be deserialized with load(), which is usually used to load from string, otherwise, the root object is in a list or dict.

# %%
import json

json_var ="""
{
    "Country": {
        "name": "INDIA",
        "Languages_spoken": [
            {
                "names": ["Hindi", "English", "Bengali", "Telugu"]
            }
        ]
    }
}
"""
var = json.loads(json_var)
var
# Out:
# {'Country': {'name': 'INDIA',
#   'Languages_spoken': [{'names': ['Hindi', 'English', 'Bengali', 'Telugu']}]}}

# %% [markdown]
# ### 7. What function takes a Python data structure and returns a string of JSON data?

# %% [markdown]
# ![image.png](attachment:70aec0e3-8e9d-4223-9aa7-a7b53459d8b3.png)

# %%
var
# Out:
# {'Country': {'name': 'INDIA',
#   'Languages_spoken': [{'names': ['Hindi', 'English', 'Bengali', 'Telugu']}]}}

# %%
with open("Sample.json", "w") as p:
     json.dump(var, p)

# %% [markdown]
# ![image.png](attachment:daf2e258-35a5-40e4-b365-4e1ece6c43b7.png)
