# %% [markdown]
# # Assignment Stats1

# %% [markdown]
# ### Calculate the mean, median, mode and standard deviation for the problem statements 1& 2.

# %% [markdown]
# Problem Statement 1:
# The marks awarded for an assignment set for a Year 8 class of 20 students were as
# follows:
# 6 7 5 7 7 8 7 6 9 7 4 10 6 8 8 9 5 6 4 8

# %%
marks=[6, 7, 5, 7, 7, 8, 7, 6, 9, 7, 4, 10, 6, 8, 8, 9, 5, 6, 4, 8]

# %%
import statistics as st
_mean = st.mean(marks)
_median = st.median(marks)
_mode = st.mode(marks)
_sd = st.pstdev(marks)
print("mean:",_mean)
print("median:",_median)
print("mode:",_mode)
print("standard deviation:",_sd)
# Out:
# mean: 6.85
# median: 7.0
# mode: 7
# standard deviation: 1.5898113095584647

# %%
# mean
_sum=6+7+5+7+7+8+7+6+9+7+4+10+6+8+8+9+5+6+4+8
_sum/20
# Out:
# 6.85

# %%
# median
sorted(marks)[10]
# Out:
# 7

# %%
dict((i,marks.count(i)) for i in marks)
# Out:
# {4: 2, 5: 2, 6: 4, 7: 5, 8: 4, 9: 2, 10: 1}

# %%
# mode
x = max(marks, key=marks.count)
x
# Out:
# 7

# %%
# standard deviation
_mean = sum(marks)/len(marks)
_variance = sum([((x - _mean)**2) for x in marks])/len(marks)
_sd = _variance ** 0.5
_sd
# Out:
# 1.5898113095584647

# %% [markdown]
# ### Problem Statement 2:
# The number of calls from motorists per day for roadside service was recorded for a
# particular month:
# 28, 122, 217, 130, 120, 86, 80, 90, 140, 120, 70, 40, 145, 113, 90, 68, 174, 194, 170,
# 100, 75, 104, 97, 75,
# 123, 100, 75, 104, 97, 75, 123, 100, 89, 120, 109

# %%
_list = [28, 122, 217, 130, 120, 86, 80, 90, 140, 120, 70, 40, 145, 113, 90, 68, 174, 194, 170, 100, 75, 104, 97, 75, 123, 100, 75, 104, 97, 75, 123, 100, 89, 120, 109]

# %%
import statistics as st
_mean = st.mean(_list)
_median = st.median(_list)
_mode = st.mode(_list)
_sd = st.pstdev(_list)
print("mean:",_mean)
print("median:",_median)
print("mode:",_mode)
print("standard deviation:",_sd)
# Out:
# mean: 107.51428571428572
# median: 100
# mode: 75
# standard deviation: 38.77287080168403

# %% [markdown]
# ### Problem Statement 3:
# The number of times I go to the gym in weekdays, are given below along with its
# associated probability:
# x = 0, 1, 2, 3, 4, 5
# f(x) = 0.09, 0.15, 0.40, 0.25, 0.10, 0.01
# Calculate the mean no. of workouts in a week. Also evaluate the variance involved in
# it.

# %% [markdown]
# ![image.png](attachment:fdd3db29-e6a7-4e23-9e3d-c50f5ecc140a.png)

# %%
x=[0,1,2,3,4,5]
p_x=[0.09,0.15,0.4,0.25,0.1,0.01]

# %%
# mean
_mean = sum([(x * p_x) for x, p_x in zip(x,p_x)])
print("mean:",_mean)
# Out:
# mean: 2.15

# %%
# variance
_diff2 = [(xi - _mean)**2 for xi in x]
_variance = sum([(_diff2*p_x) for _diff2,p_x in zip (_diff2,p_x)])
_sd = _variance ** 0.5
print("variance:",_variance)
print("standard deviation:", _sd)
# Out:
# variance: 1.2275
# standard deviation: 1.107925990308017

# %%
import pandas as pd
_mean = 2.15
df=pd.DataFrame(x, columns=["x"])
df["p_x"]=p_x
df["x*p_x"]=[x*p_x for x,p_x in zip(x,p_x)]
df["(x - mean)^2"]=[(xi - _mean)**2 for xi in x]
df["(x - mean)^2 * p_x"]=[(_diff2*p_x) for _diff2,p_x in zip (_diff2,p_x)]
df["mean"] = sum(df["x*p_x"])
df["variance"] = sum(df["(x - mean)^2 * p_x"])
df
# Out:
#    x   p_x  x*p_x  (x - mean)^2  (x - mean)^2 * p_x  mean  variance
# 0  0  0.09   0.00        4.6225            0.416025  2.15    1.2275
# 1  1  0.15   0.15        1.3225            0.198375  2.15    1.2275
# 2  2  0.40   0.80        0.0225            0.009000  2.15    1.2275
# 3  3  0.25   0.75        0.7225            0.180625  2.15    1.2275
# 4  4  0.10   0.40        3.4225            0.342250  2.15    1.2275
# 5  5  0.01   0.05        8.1225            0.081225  2.15    1.2275

# %% [markdown]
# ### Problem Statement 4:
# Let the continuous random variable D denote the diameter of the hole drilled in an
# aluminum sheet. The target diameter to be achieved is 12.5mm. Random
# disturbances in the process often result in inaccuracy.
# Historical data shows that the distribution of D can be modelled by the PDF (d) =
# 20e−20(d−12.5), d ≥ 12.5. If a part with diameter > 12.6 mm needs to be scrapped,
# what is the proportion of those parts? What is the CDF when the diameter is of 11
# mm? What is your conclusion regarding the proportion of scraps?

# %% [markdown]
# Based on the conditions, the proportion of parts scrapped with a diameter > 12.6mm is calculate by:
# ![image.png](attachment:944c962c-8c52-4c56-b613-d29eba60323d.png)

# %% [markdown]
# * What is the CDF when the diameter is of 11 mm? : it should be equal to ZERO since the PDF equation starts only for values d ≥ 12.5.

# %% [markdown]
# * Proportions for scraps P(12.5 < X < x) - proprotion of parts between 12.5 and x is given by:
#   ![image.png](attachment:0495d823-cc77-4e0c-9914-5fbb398523b1.png)

# %% [markdown]
# ### Problem Statement 5:
#
# A company manufactures LED bulbs with a faulty rate of 30%. If I randomly select 6
# chosen LEDs, what is the probability of having 2 faulty LEDs in my sample?
# Calculate the average value of this process. Also evaluate the standard deviation
# associated with it.

# %% [markdown]
# ![image.png](attachment:297a78d5-9f33-40ee-a3f0-8347f0fa144f.png)

# %%
# manual calculation: probability of getting faulty out of 6 trials

import math

p_faulty=0.3                # probability of faulty
p_nofaulty = 1 - p_faulty   # probability of no faulty
n=6                         # total number of trials
x=2                         # number of trails that will be succcessed

# P(x=2/n=6)
P = ((math.factorial(n)) / (math.factorial(n-x)*math.factorial(x))) * (p_faulty**(x)) * (p_nofaulty**(n-x))
print(f"Probability will be : {P:3.3f}")
# Out:
# Probability will be : 0.324

# %%
mean = n*p_faulty             # mean is np
var= n*p_faulty*p_nofaulty    # variance is npq
print(f"mean : {mean:6.3f}")
print(f"standard deviation : {math.sqrt(var):6.3f}")
# Out:
# mean :  1.800
# standard deviation :  1.122

# %%
# library calculation: probability of getting faulty out of 6 trials

from scipy.stats import binom

P = binom.pmf(k=2, n=6, p=0.3)
print(f"Probability will be : {P:3.3f}")
# Out:
# Probability will be : 0.324

# %%
mean,var=binom.stats(n=6,p=0.3, moments='mv')
print(f"mean : {mean:6.3f}")
print(f"standard deviation : {math.sqrt(var):6.3f}")
# Out:
# mean :  1.800
# standard deviation :  1.122

# %% [markdown]
# # Problem Statement 6:
#
# Gaurav and Barakha are both preparing for entrance exams. Gaurav attempts to
# solve 8 questions per day with a correction rate of 75%, while Barakha averages
# around 12 questions per day with a correction rate of 45%. What is the probability
# that each of them will solve 5 questions correctly? What happens in cases of 4 and 6
# correct solutions? What do you infer from it? What are the two main governing
# factors affecting their ability to solve questions correctly? Give a pictorial
# representation of the same to validate your answer.

# %% [markdown]
# * https://www.youtube.com/watch?v=xNLQuuvE9ug&t=54s
# ![image.png](attachment:e831cf5f-25c5-47bf-80a3-48fb8e77c983.png)

# %%
# given parameters:
ng = 8      # Guarav number of independen tirals
p_g = 0.75  # probability of success ng
q_g = 0.25  # probability of failure ng
nb = 12     # Barakha number of independen tirals
p_b = 0.45  # probability of succes nb
q_b = 0.55  # probability of failure nb
x1=5        # solve x1 questinos correctly
x2=4        # solve x2 questinos correctly
x3=6        # solve x33 questinos correctly

# %% [markdown]
# * For Guarav: solving 5 questions correctly
#
# ![image.png](attachment:79796caa-b195-429e-a2c1-9f8096f6fe2e.png)

# %%
# P(x1=5/ng=8)
Px1_g = ((math.factorial(ng)) / (math.factorial(ng-x1)*math.factorial(x1))) * (p_g**(x1)) * (q_g**(ng-x1))
print(f"Probability of x={x1} will be : {Px1_g:3.3f}")
# P(x2=4/ng=8)
Px2_g = ((math.factorial(ng)) / (math.factorial(ng-x2)*math.factorial(x2))) * (p_g**(x2)) * (q_g**(ng-x2))
print(f"Probability of x={x2} will be : {Px2_g:3.3f}")
# P(x3=6/ng=8)
Px3_g = ((math.factorial(ng)) / (math.factorial(ng-x3)*math.factorial(x3))) * (p_g**(x3)) * (q_g**(ng-x3))
print(f"Probability of x={x3} will be : {Px3_g:3.3f}")
# Out:
# Probability of x=5 will be : 0.208
# Probability of x=4 will be : 0.087
# Probability of x=6 will be : 0.311

# %% [markdown]
# * For Barkha: solving 5 questions correctly
#
# ![image.png](attachment:b8d49811-9d3d-48a6-9cc0-bb049be4fe2a.png)

# %%
# P(x=5/nb=12)
Px1_b = ((math.factorial(nb)) / (math.factorial(nb-x1)*math.factorial(x1))) * (p_b**(x1)) * (q_b**(nb-x1))
print(f"Probability of x={x1} will be : {Px1_b:3.3f}")
# P(x2=4/nb=12)
Px2_b = ((math.factorial(nb)) / (math.factorial(nb-x2)*math.factorial(x2))) * (p_b**(x2)) * (q_b**(nb-x2))
print(f"Probability of x={x2} will be : {Px2_b:3.3f}")
# P(x3=6/nb=12)
Px3_b = ((math.factorial(nb)) / (math.factorial(nb-x3)*math.factorial(x3))) * (p_b**(x3)) * (q_b**(nb-x3))
print(f"Probability of x={x3} will be : {Px3_b:3.3f}")
# Out:
# Probability of x=5 will be : 0.222
# Probability of x=4 will be : 0.170
# Probability of x=6 will be : 0.212

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.title("Probability Distribution - Gaurav's ",fontsize=16)
plt.xlabel("Questions Solved Correctly",fontsize=16)
plt.ylabel("Probability of solving questions correctly",fontsize=16)
plt.bar([4,5,6], [0.087,0.208,0.311])
plt.ylim([0,0.35])
plt.text(4,0.3,'solved questions per day: 8',fontsize=16)
plt.text(4,0.28,'correction Rate = 0.75',fontsize=16)
plt.subplot(1, 2, 2)
plt.title("Probability Distribution - Barkha's ",fontsize=16)
plt.xlabel("Questions Solved Correctly",fontsize=16)
plt.ylabel("Probability of solving questions correctly",fontsize=16)
plt.bar([4,5,6], [0.170,0.222,0.212]) 
plt.ylim([0,0.35])
plt.text(4,0.3,'solved questions per day: 12',fontsize=16)
plt.text(4,0.28,'correction Rate = 0.45',fontsize=16)
plt.show()

# %% [markdown]
# ### Conclusion
# * it appears that the probability of solving increases with a higher correction rate
# * it appears that solving more questions per day provide a more stable amount of questions solved correctly
